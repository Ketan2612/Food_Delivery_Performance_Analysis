# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/cleaned_food_delivery_data.csv")

# %%
df.head()
# Out:
#   Traffic_Level    ID Delivery_person_ID weather_description Type_of_order  \
# 0          High  70A2     CHENRES12DEL01                mist         Snack
# 1          High  95B4   RANCHIRES15DEL01           clear sky          Meal
# 2          High  CDCD      DEHRES17DEL01           clear sky         Snack
# 3          High  2784     PUNERES13DEL03           clear sky        Drinks
# 4          High  6F67      HYDRES14DEL01     overcast clouds         Snack
#
#   Type_of_vehicle  Delivery_person_Age  Delivery_person_Ratings  \
# 0         scooter                   32                      4.6
# 1         scooter                   33                      4.7
# 2      motorcycle                   36                      4.2
# 3         scooter                   23                      4.7
# 4      motorcycle                   34                      4.9
#
#   Restaurant_latitude Restaurant_longitude Delivery_location_latitude  \
# ...

# %%
df.shape
# Out:
# (10000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Traffic_Level                9085 non-null   object
#  1   ID                           10000 non-null  object
#  2   Delivery_person_ID           10000 non-null  object
#  3   weather_description          9995 non-null   object
#  4   Type_of_order                10000 non-null  object
#  5   Type_of_vehicle              10000 non-null  object
#  6   Delivery_person_Age          10000 non-null  int64
#  7   Delivery_person_Ratings      10000 non-null  float64
#  8   Restaurant_latitude          10000 non-null  object
#  9   Restaurant_longitude         10000 non-null  object
#  10  Delivery_location_latitude   10000 non-null  object
#  11  Delivery_location_longitude  10000 non-null  object
#  12  temperature                  10000 non-null  float64
# ...

# %%
df.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings   temperature  \
# count         10000.000000             10000.000000  10000.000000
# mean             29.522000                 4.627998     22.936907
# std               5.700348                 0.320016      3.378603
# min              15.000000                 1.000000      6.770000
# 25%              25.000000                 4.500000     20.140000
# 50%              29.000000                 4.700000     22.990000
# 75%              34.000000                 4.800000     25.980000
# max              50.000000                 5.000000     29.050000
#
#            humidity  precipitation  Distance (km)        TARGET
# count  10000.000000   10000.000000   10000.000000  10000.000000
# mean      66.164882       0.016233      14.292747     32.437977
# std       15.599037       0.074893       7.981611     18.831052
# min       27.000000       0.000000       1.550000      0.080000
# ...

# %%
df["TARGET"].describe()
# Out:
# count    10000.000000
# mean        32.437977
# std         18.831052
# min          0.080000
# 25%         19.960000
# 50%         32.437977
# 75%         43.880000
# max         99.850000
# Name: TARGET, dtype: float64

# %%
sns.histplot(df["TARGET"], bins=30)
plt.title("Distribution of Delivery Time")
plt.show()

# %%
df["Traffic_Level"].value_counts()
# Out:
# Traffic_Level
# High         2736
# Moderate     2219
# Very High    1772
# Low          1726
# Very Low      632
# Name: count, dtype: int64

# %%
sns.countplot(x="Traffic_Level", data=df)
plt.show()

# %%
df["Type_of_order"].value_counts()
# Out:
# Type_of_order
# Snack     2551
# Meal      2530
# Drinks    2507
# Buffet    2412
# Name: count, dtype: int64

# %%
sns.countplot(x="Type_of_order", data=df)
plt.show()

# %%
df["Type_of_vehicle"].value_counts()
# Out:
# Type_of_vehicle
# motorcycle          5862
# scooter             3304
# electric_scooter     814
# bicycle               20
# Name: count, dtype: int64

# %%
sns.countplot(x="Type_of_vehicle", data=df)
plt.show()

# %%
sns.histplot(df["Delivery_person_Age"], bins=20)
plt.title("Delivery Partner Age Distribution")
plt.show()

# %%
sns.histplot(df["Delivery_person_Ratings"], bins=20)
plt.title("Ratings Distribution")
plt.show()

# %%
sns.histplot(df["Distance (km)"], bins=30)
plt.title("Distance Distribution")
plt.show()

# %%
df["weather_description"].value_counts()
# Out:
# weather_description
# clear sky           3260
# haze                2406
# mist                1751
# broken clouds        721
# light rain           536
# smoke                501
# scattered clouds     422
# overcast clouds      308
# fog                   49
# few clouds            40
# moderate rain          1
# Name: count, dtype: int64

# %%
sns.countplot(x="weather_description", data=df)
plt.xticks(rotation=45)
plt.show()

# %%
sns.scatterplot(x="Distance (km)", y="TARGET", data=df)
plt.show()

# %%
df.groupby("Traffic_Level")["TARGET"].mean()
# Out:
# Traffic_Level
# High         36.512817
# Low          17.751595
# Moderate     26.654532
# Very High    52.058060
# Very Low     20.201598
# Name: TARGET, dtype: float64

# %%
sns.boxplot(x="Traffic_Level", y="TARGET", data=df)
plt.show()

# %%
df.groupby("Type_of_vehicle")["TARGET"].mean()
# Out:
# Type_of_vehicle
# bicycle             29.791988
# electric_scooter    32.326520
# motorcycle          32.486732
# scooter             32.394950
# Name: TARGET, dtype: float64

# %%
df.groupby("weather_description")["TARGET"].mean()
# Out:
# weather_description
# broken clouds       33.261300
# clear sky           33.677224
# few clouds          32.468500
# fog                 47.163469
# haze                28.743497
# light rain          32.437977
# mist                29.473854
# moderate rain       66.450000
# overcast clouds     44.600893
# scattered clouds    37.798942
# smoke               37.787772
# Name: TARGET, dtype: float64

# %%
corr = df[[
"Delivery_person_Age",
"Delivery_person_Ratings",
"Distance (km)",
"temperature",
"humidity",
"precipitation",
"TARGET"
]].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %%
sns.boxplot(x=df["TARGET"])
plt.show()
